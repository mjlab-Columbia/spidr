# %%
import pandas as pd
from scipy.cluster.hierarchy import fcluster, linkage
import scipy.cluster.hierarchy as sch
import os
import matplotlib.pyplot as plt
import pybedtools

# %%
directory1 = 'output/'
protein_file = 'protein_list.txt'
outfile_prefix = 'SPIDR_filtered_annotation_miRNA_adj'

# %%
annotations1 = []

for file in os.listdir(directory1):
    annotations1.append(file)

# %%
set1_annotations = []
for i in annotations1:
    annotations_file=directory1+i

    with open(annotations_file) as file:
        annotations_df = pd.read_csv(file, header=None, sep='\t')
        annotations_df.columns = ['chrom', 'chromStart', 'chromEnd', 'name', 'count','strand', 'ens', 'gene', 'annotation', 'other']
        set1_annotations.append(annotations_df)

# %%
updated = []
for i in set1_annotations:
    for ind in i.index:
        gene = i.at[int(ind), 'gene']
        annotation = i.at[int(ind), 'annotation']
        if 'MIR' in gene and 'miRNA' not in annotation:
            i.at[int(ind), 'annotation'] = 'miRNA_adjacent'
    
    updated.append(i)

# %%
for i in range(len(updated)):
    prefix = annotations1[i][:-4]
    filename = prefix + '.bed'
    pybedtools.BedTool.from_dataframe(updated[i]).saveas(filename)

# %%
set1_annotations = updated

# %%
# get absolute peak counts for each annotation
annotation_dict_list1 = []

for i in set1_annotations:
    annotation_dict = {}

    for ind in i.index:
        annotation = i['annotation'][ind]
        if annotation in annotation_dict.keys():
            annotation_dict[annotation] = annotation_dict[annotation] + 1
        else:
            annotation_dict[annotation] = 1
    
    annotation_dict_list1.append(annotation_dict)

# %%
# get all keys
all_keys = []
for i in annotation_dict_list1:
    for key in i.keys():
        if key not in all_keys:
            all_keys.append(key)

all_keys = sorted(all_keys)
all_keys
# Out:
# ['3utr',
#  '5utr',
#  'CDS',
#  'distintron500',
#  'distnoncoding_intron500',
#  'intergenic',
#  'miRNA',
#  'miRNA_adjacent',
#  'noncoding_exon',
#  'proxintron500',
#  'proxnoncoding_intron500',
#  'stop_codon']

# %%
# add values to each dictionary for each annotation
for i in annotation_dict_list1:
    for category in all_keys:
        if category not in i.keys():
            i[category] = 0
            
# convert dictionary
annotation_summary = pd.DataFrame(annotation_dict_list1)
annotation_summary = annotation_summary.transpose()
annotation_summary.columns = annotations1

# %%
annotation_summary
# Out:
#                          HNRNPL_Bethyl_spidr_annotation.txt  \
# noncoding_exon                                          122
# distnoncoding_intron500                                 622
# distintron500                                          1184
# intergenic                                             3800
# proxintron500                                           143
# CDS                                                      24
# 3utr                                                     63
# proxnoncoding_intron500                                  86
# 5utr                                                      6
# stop_codon                                                1
# miRNA_adjacent                                            1
# miRNA                                                     0
#
#                          PTBP1_spidr_annotation.txt  \
# noncoding_exon                                  852
# distnoncoding_intron500                        8171
# distintron500                                 42145
# intergenic                                     7298
# proxintron500                                  5250
# CDS                                             977
# 3utr                                           2352
# proxnoncoding_intron500                         579
# 5utr                                            412
# stop_codon                                        6
# miRNA_adjacent                                  127
# miRNA                                            11
#
#                          HNRNPC_spidr_annotation.txt  \
# noncoding_exon                                   213
# distnoncoding_intron500                          330
# distintron500                                   6513
# intergenic                                       764
# proxintron500                                    595
# CDS                                              104
# 3utr                                             188
# proxnoncoding_intron500                          128
# 5utr                                              98
# stop_codon                                         0
# miRNA_adjacent                                     1
# miRNA                                              0
#
#                          WDR43_spidr_annotation.txt  \
# noncoding_exon                                   11
# distnoncoding_intron500                           1
# distintron500                                     0
# intergenic                                      282
# proxintron500                                     0
# CDS                                               0
# 3utr                                              0
# proxnoncoding_intron500                           2
# 5utr                                              0
# stop_codon                                        0
# miRNA_adjacent                                    0
# miRNA                                             0
#
#                          PCBP2_spidr_annotation.txt  \
# noncoding_exon                                   38
# distnoncoding_intron500                          41
# distintron500                                   272
# intergenic                                       49
# proxintron500                                   131
# CDS                                             162
# 3utr                                            193
# proxnoncoding_intron500                           8
# 5utr                                             56
# stop_codon                                        2
# miRNA_adjacent                                   12
# miRNA                                             1
#
#                          HNRNPL_CST_spidr_annotation.txt  \
# noncoding_exon                                        76
# distnoncoding_intron500                              609
# distintron500                                       2413
# intergenic                                          1993
# proxintron500                                        331
# CDS                                                  130
# 3utr                                                 161
# proxnoncoding_intron500                               68
# 5utr                                                  20
# stop_codon                                             0
# miRNA_adjacent                                         3
# miRNA                                                  0
#
#                          SSB_spidr_annotation.txt  \
# noncoding_exon                                  7
# distnoncoding_intron500                         4
# distintron500                                   3
# intergenic                                     72
# proxintron500                                   4
# CDS                                             5
# 3utr                                            0
# proxnoncoding_intron500                         4
# 5utr                                            0
# stop_codon                                      0
# miRNA_adjacent                                  1
# miRNA                                           0
#
#                          FASTKD2_spidr_annotation.txt  \
# noncoding_exon                                     15
# distnoncoding_intron500                             1
# distintron500                                       6
# intergenic                                          2
# proxintron500                                      30
# CDS                                                63
# 3utr                                                4
# proxnoncoding_intron500                             3
# 5utr                                               15
# stop_codon                                          0
# miRNA_adjacent                                      0
# miRNA                                               0
#
#                          IGF2BP1_spidr_annotation.txt  \
# noncoding_exon                                    117
# distnoncoding_intron500                            18
# distintron500                                    1138
# intergenic                                        270
# proxintron500                                     318
# CDS                                               386
# 3utr                                              275
# proxnoncoding_intron500                             1
# 5utr                                               33
# stop_codon                                          1
# miRNA_adjacent                                      2
# miRNA                                               3
#
#                          SLBP_spidr_annotation.txt  ...  \
# noncoding_exon                                  16  ...
# distnoncoding_intron500                         31  ...
# distintron500                                    0  ...
# intergenic                                     234  ...
# proxintron500                                    0  ...
# CDS                                             45  ...
# 3utr                                            19  ...
# proxnoncoding_intron500                          5  ...
# 5utr                                             1  ...
# stop_codon                                       0  ...
# miRNA_adjacent                                   0  ...
# miRNA                                            0  ...
#
#                          IGF2BP2_spidr_annotation.txt  \
# noncoding_exon                                      0
# distnoncoding_intron500                             0
# distintron500                                       0
# intergenic                                          0
# proxintron500                                       1
# CDS                                                 3
# 3utr                                                3
# proxnoncoding_intron500                             0
# 5utr                                                1
# stop_codon                                          0
# miRNA_adjacent                                      1
# miRNA                                               0
#
#                          HuR_spidr_annotation.txt  LSM11_spidr_annotation.txt  \
# noncoding_exon                                105                           2
# distnoncoding_intron500                       349                           0
# distintron500                                2373                          61
# intergenic                                    771                          41
# proxintron500                                 369                           6
# CDS                                           131                           0
# 3utr                                         1062                           2
# proxnoncoding_intron500                        49                           0
# 5utr                                           87                           0
# stop_codon                                      1                           0
# miRNA_adjacent                                  5                           0
# miRNA                                           4                           0
#
#                          ILF3_spidr_annotation.txt  \
# noncoding_exon                                 286
# distnoncoding_intron500                       2022
# distintron500                                13577
# intergenic                                    1715
# proxintron500                                 1255
# CDS                                            163
# 3utr                                           835
# proxnoncoding_intron500                        138
# 5utr                                            80
# stop_codon                                       2
# miRNA_adjacent                                   8
# miRNA                                            5
#
#                          FUBP3_spidr_annotation.txt  \
# noncoding_exon                                 3145
# distnoncoding_intron500                       15947
# distintron500                                 47845
# intergenic                                    15605
# proxintron500                                  3141
# CDS                                            4656
# 3utr                                           2319
# proxnoncoding_intron500                        1022
# 5utr                                            314
# stop_codon                                       10
# miRNA_adjacent                                 1322
# miRNA                                            11
#
#                          SRSF9_spidr_annotation.txt  \
# noncoding_exon                                   97
# distnoncoding_intron500                           2
# distintron500                                  2352
# intergenic                                       12
# proxintron500                                    43
# CDS                                              15
# 3utr                                              4
# proxnoncoding_intron500                           1
# 5utr                                              7
# stop_codon                                        0
# miRNA_adjacent                                    0
# miRNA                                             1
#
#                          LIN28B_spidr_annotation.txt  \
# noncoding_exon                                    31
# distnoncoding_intron500                            0
# distintron500                                     94
# intergenic                                        40
# proxintron500                                     88
# CDS                                              159
# 3utr                                              81
# proxnoncoding_intron500                            5
# 5utr                                               9
# stop_codon                                         1
# miRNA_adjacent                                     0
# miRNA                                              5
#
#                          ADAR1_spidr_annotation.txt  \
# noncoding_exon                                  158
# distnoncoding_intron500                         393
# distintron500                                   153
# intergenic                                      140
# proxintron500                                    10
# CDS                                             368
# 3utr                                             86
# proxnoncoding_intron500                          13
# 5utr                                              9
# stop_codon                                        2
# miRNA_adjacent                                    0
# miRNA                                             0
#
#                          EWSR1_spidr_annotation.txt  RPS3_spidr_annotation.txt
# noncoding_exon                                  578                         16
# distnoncoding_intron500                         214                          0
# distintron500                                  2269                          1
# intergenic                                      688                         16
# proxintron500                                  3897                          1
# CDS                                            5648                         20
# 3utr                                            663                          1
# proxnoncoding_intron500                         129                          0
# 5utr                                            474                          0
# stop_codon                                        3                          0
# miRNA_adjacent                                   16                          0
# miRNA                                            38                          0
#
# [12 rows x 46 columns]

# %%
# remove intergenic 
annotation_summary = annotation_summary.drop(['intergenic'])
annotation_filename = outfile_prefix + '_counts.csv'
annotation_summary.to_csv(annotation_filename)
# get proportion 

proportion_summary = annotation_summary

for i in annotations1:
    colsum = proportion_summary[i].sum()
    proportion_summary[i] = proportion_summary[i].div(colsum)
    proportion_summary[i] = proportion_summary[i].multiply(100).round(2)

# %%
proportion_summary
# Out:
#                          HNRNPL_Bethyl_spidr_annotation.txt  \
# noncoding_exon                                         5.42
# distnoncoding_intron500                               27.62
# distintron500                                         52.58
# proxintron500                                          6.35
# CDS                                                    1.07
# 3utr                                                   2.80
# proxnoncoding_intron500                                3.82
# 5utr                                                   0.27
# stop_codon                                             0.04
# miRNA_adjacent                                         0.04
# miRNA                                                  0.00
#
#                          PTBP1_spidr_annotation.txt  \
# noncoding_exon                                 1.40
# distnoncoding_intron500                       13.42
# distintron500                                 69.22
# proxintron500                                  8.62
# CDS                                            1.60
# 3utr                                           3.86
# proxnoncoding_intron500                        0.95
# 5utr                                           0.68
# stop_codon                                     0.01
# miRNA_adjacent                                 0.21
# miRNA                                          0.02
#
#                          HNRNPC_spidr_annotation.txt  \
# noncoding_exon                                  2.61
# distnoncoding_intron500                         4.04
# distintron500                                  79.72
# proxintron500                                   7.28
# CDS                                             1.27
# 3utr                                            2.30
# proxnoncoding_intron500                         1.57
# 5utr                                            1.20
# stop_codon                                      0.00
# miRNA_adjacent                                  0.01
# miRNA                                           0.00
#
#                          WDR43_spidr_annotation.txt  \
# noncoding_exon                                78.57
# distnoncoding_intron500                        7.14
# distintron500                                  0.00
# proxintron500                                  0.00
# CDS                                            0.00
# 3utr                                           0.00
# proxnoncoding_intron500                       14.29
# 5utr                                           0.00
# stop_codon                                     0.00
# miRNA_adjacent                                 0.00
# miRNA                                          0.00
#
#                          PCBP2_spidr_annotation.txt  \
# noncoding_exon                                 4.15
# distnoncoding_intron500                        4.48
# distintron500                                 29.69
# proxintron500                                 14.30
# CDS                                           17.69
# 3utr                                          21.07
# proxnoncoding_intron500                        0.87
# 5utr                                           6.11
# stop_codon                                     0.22
# miRNA_adjacent                                 1.31
# miRNA                                          0.11
#
#                          HNRNPL_CST_spidr_annotation.txt  \
# noncoding_exon                                      1.99
# distnoncoding_intron500                            15.98
# distintron500                                      63.32
# proxintron500                                       8.69
# CDS                                                 3.41
# 3utr                                                4.22
# proxnoncoding_intron500                             1.78
# 5utr                                                0.52
# stop_codon                                          0.00
# miRNA_adjacent                                      0.08
# miRNA                                               0.00
#
#                          SSB_spidr_annotation.txt  \
# noncoding_exon                              25.00
# distnoncoding_intron500                     14.29
# distintron500                               10.71
# proxintron500                               14.29
# CDS                                         17.86
# 3utr                                         0.00
# proxnoncoding_intron500                     14.29
# 5utr                                         0.00
# stop_codon                                   0.00
# miRNA_adjacent                               3.57
# miRNA                                        0.00
#
#                          FASTKD2_spidr_annotation.txt  \
# noncoding_exon                                  10.95
# distnoncoding_intron500                          0.73
# distintron500                                    4.38
# proxintron500                                   21.90
# CDS                                             45.99
# 3utr                                             2.92
# proxnoncoding_intron500                          2.19
# 5utr                                            10.95
# stop_codon                                       0.00
# miRNA_adjacent                                   0.00
# miRNA                                            0.00
#
#                          IGF2BP1_spidr_annotation.txt  \
# noncoding_exon                                   5.10
# distnoncoding_intron500                          0.79
# distintron500                                   49.65
# proxintron500                                   13.87
# CDS                                             16.84
# 3utr                                            12.00
# proxnoncoding_intron500                          0.04
# 5utr                                             1.44
# stop_codon                                       0.04
# miRNA_adjacent                                   0.09
# miRNA                                            0.13
#
#                          SLBP_spidr_annotation.txt  ...  \
# noncoding_exon                               13.68  ...
# distnoncoding_intron500                      26.50  ...
# distintron500                                 0.00  ...
# proxintron500                                 0.00  ...
# CDS                                          38.46  ...
# 3utr                                         16.24  ...
# proxnoncoding_intron500                       4.27  ...
# 5utr                                          0.85  ...
# stop_codon                                    0.00  ...
# miRNA_adjacent                                0.00  ...
# miRNA                                         0.00  ...
#
#                          IGF2BP2_spidr_annotation.txt  \
# noncoding_exon                                   0.00
# distnoncoding_intron500                          0.00
# distintron500                                    0.00
# proxintron500                                   11.11
# CDS                                             33.33
# 3utr                                            33.33
# proxnoncoding_intron500                          0.00
# 5utr                                            11.11
# stop_codon                                       0.00
# miRNA_adjacent                                  11.11
# miRNA                                            0.00
#
#                          HuR_spidr_annotation.txt  LSM11_spidr_annotation.txt  \
# noncoding_exon                               2.32                        2.82
# distnoncoding_intron500                      7.70                        0.00
# distintron500                               52.33                       85.92
# proxintron500                                8.14                        8.45
# CDS                                          2.89                        0.00
# 3utr                                        23.42                        2.82
# proxnoncoding_intron500                      1.08                        0.00
# 5utr                                         1.92                        0.00
# stop_codon                                   0.02                        0.00
# miRNA_adjacent                               0.11                        0.00
# miRNA                                        0.09                        0.00
#
#                          ILF3_spidr_annotation.txt  \
# noncoding_exon                                1.56
# distnoncoding_intron500                      11.01
# distintron500                                73.90
# proxintron500                                 6.83
# CDS                                           0.89
# 3utr                                          4.55
# proxnoncoding_intron500                       0.75
# 5utr                                          0.44
# stop_codon                                    0.01
# miRNA_adjacent                                0.04
# miRNA                                         0.03
#
#                          FUBP3_spidr_annotation.txt  \
# noncoding_exon                                 3.94
# distnoncoding_intron500                       20.00
# distintron500                                 60.01
# proxintron500                                  3.94
# CDS                                            5.84
# 3utr                                           2.91
# proxnoncoding_intron500                        1.28
# 5utr                                           0.39
# stop_codon                                     0.01
# miRNA_adjacent                                 1.66
# miRNA                                          0.01
#
#                          SRSF9_spidr_annotation.txt  \
# noncoding_exon                                 3.85
# distnoncoding_intron500                        0.08
# distintron500                                 93.26
# proxintron500                                  1.70
# CDS                                            0.59
# 3utr                                           0.16
# proxnoncoding_intron500                        0.04
# 5utr                                           0.28
# stop_codon                                     0.00
# miRNA_adjacent                                 0.00
# miRNA                                          0.04
#
#                          LIN28B_spidr_annotation.txt  \
# noncoding_exon                                  6.55
# distnoncoding_intron500                         0.00
# distintron500                                  19.87
# proxintron500                                  18.60
# CDS                                            33.62
# 3utr                                           17.12
# proxnoncoding_intron500                         1.06
# 5utr                                            1.90
# stop_codon                                      0.21
# miRNA_adjacent                                  0.00
# miRNA                                           1.06
#
#                          ADAR1_spidr_annotation.txt  \
# noncoding_exon                                13.26
# distnoncoding_intron500                       32.97
# distintron500                                 12.84
# proxintron500                                  0.84
# CDS                                           30.87
# 3utr                                           7.21
# proxnoncoding_intron500                        1.09
# 5utr                                           0.76
# stop_codon                                     0.17
# miRNA_adjacent                                 0.00
# miRNA                                          0.00
#
#                          EWSR1_spidr_annotation.txt  RPS3_spidr_annotation.txt
# noncoding_exon                                 4.15                      41.03
# distnoncoding_intron500                        1.54                       0.00
# distintron500                                 16.29                       2.56
# proxintron500                                 27.98                       2.56
# CDS                                           40.55                      51.28
# 3utr                                           4.76                       2.56
# proxnoncoding_intron500                        0.93                       0.00
# 5utr                                           3.40                       0.00
# stop_codon                                     0.02                       0.00
# miRNA_adjacent                                 0.11                       0.00
# miRNA                                          0.27                       0.00
#
# [11 rows x 46 columns]

# %%
proportion_filename = outfile_prefix + '_percentage.csv'
proportion_summary.to_csv(proportion_filename)
